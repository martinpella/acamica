# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('fut19.csv')
# Out:
# /home/martinpella/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (75,76,77,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (16554, 84)

# %%
df.head().T
# Out:
#                                                                       0  \
# player_ID                                                             1
# player_name                                                        Pelé
# player_extended_name                           Arantes Nascimento Edson
# quality                                                     Gold - Rare
# revision                                                           Icon
# origin                                                              NaN
# overall                                                              98
# club                                                              Icons
# league                                                            Icons
# nationality                                                      Brazil
# position                                                            CAM
# age                                                                  77
# ...

# %%
df.columns
# Out:
# Index(['player_ID', 'player_name', 'player_extended_name', 'quality',
#        'revision', 'origin', 'overall', 'club', 'league', 'nationality',
#        'position', 'age', 'date_of_birth', 'height', 'weight', 'intl_rep',
#        'added_date', 'pace', 'pace_acceleration', 'pace_sprint_speed',
#        'dribbling', 'drib_agility', 'drib_balance', 'drib_reactions',
#        'drib_ball_control', 'drib_dribbling', 'drib_composure', 'shooting',
#        'shoot_positioning', 'shoot_finishing', 'shoot_shot_power',
#        'shoot_long_shots', 'shoot_volleys', 'shoot_penalties', 'passing',
#        'pass_vision', 'pass_crossing', 'pass_free_kick', 'pass_short',
#        'pass_long', 'pass_curve', 'defending', 'def_interceptions',
#        'def_heading', 'def_marking', 'def_stand_tackle', 'def_slid_tackle',
#        'physicality', 'phys_jumping', 'phys_stamina', 'phys_strength',
#        'phys_aggression', 'gk_diving', 'gk_reflexes', 'gk_handling',
# ...

# %%
df.groupby('club')[['overall']]

# %%
df.groupby('club')[['overall']].mean()
# Out:
#                               overall
# club
# 1. FC Heidenheim 1846       66.037037
# 1. FC Kaiserslautern        63.916667
# 1. FC Köln                  70.821429
# 1. FC Magdeburg             65.576923
# 1. FC Nürnberg              68.846154
# 1. FC Union Berlin          67.866667
# 1. FSV Mainz 05             70.500000
# AC Horsens                  60.818182
# AD Alcorcón                 68.636364
# ADO Den Haag                66.440000
# AEK Athens                  72.034483
# AFC Wimbledon               61.181818
# AIK                         65.875000
# AJ Auxerre                  67.185185
# AS Béziers                  62.444444
# AS Monaco Football Club SA  75.812500
# AS Nancy Lorraine           66.625000
# AS Saint-Étienne            70.555556
# AZ                          68.933333
# Aalborg BK                  64.000000
# Aarhus GF                   61.461538
# Aberdeen                    66.222222
# Accrington Stanley          60.750000
# ...

# %%
df.groupby('club')[['overall']].mean().sort_values(by='overall', ascending=False)[:10]
# Out:
#                        overall
# club
# Icons                89.036036
# Juventus             83.764706
# Real Madrid          83.057692
# Atlético Madrid      82.977778
# FC Barcelona         82.196078
# Napoli               80.980392
# FC Bayern München    80.826923
# Paris Saint-Germain  80.509091
# Inter                80.489796
# Manchester City      80.446429

# %%
df.groupby('club')[['height', 'weight']].mean().sort_values(by='height', ascending=False)[:10]
# Out:
#                          height     weight
# club
# AC Horsens           187.181818  80.636364
# Holstein Kiel        185.700000  79.500000
# Atalanta             185.680000  79.240000
# Lokomotiv Moscow     185.475000  79.575000
# VVV-Venlo            185.360000  79.320000
# 1. FC Magdeburg      185.346154  79.115385
# FC Schalke 04        185.333333  80.291667
# SønderjyskE          185.240000  80.720000
# Cracovia             185.230769  77.653846
# SSV Jahn Regensburg  185.133333  78.966667

# %%
df.groupby([df['league'], df['nationality']])[['overall']].mean()[:10]
# Out:
#                                   overall
# league  nationality
# 3. Liga Afghanistan             63.000000
#         Albania                 63.500000
#         Argentina               65.000000
#         Australia               64.000000
#         Austria                 60.600000
#         Azerbaijan              69.000000
#         Belgium                 64.500000
#         Bosnia and Herzegovina  62.333333
#         Brazil                  62.000000
#         Cameroon                64.000000

# %%
df.groupby('position')[['pace']].median().sort_values('pace', ascending=False)
# Out:
#           pace
# position
# LF        93.0
# RW        80.0
# LW        79.0
# RM        78.0
# LWB       77.5
# CF        77.0
# LM        77.0
# RWB       76.0
# RB        74.0
# LB        73.0
# CAM       71.0
# ST        71.0
# CM        66.0
# CDM       64.0
# CB        59.0
# GK         NaN

# %% [markdown]
# ## Merge / Join

# %%
data1 = pd.DataFrame({'x1': list('abc'), 'x2': [11.432, 1.303, 99.906]})

# %%
data1
# Out:
#   x1      x2
# 0  a  11.432
# 1  b   1.303
# 2  c  99.906

# %%
data2 = pd.DataFrame({'x1': list('abd'), 'x3': [20.784,  np.NaN, 20.784]})

# %%
data2
# Out:
#   x1      x3
# 0  a  20.784
# 1  b     NaN
# 2  d  20.784

# %%
data1.merge(data2, how='inner', on='x1')
# Out:
#   x1      x2      x3
# 0  a  11.432  20.784
# 1  b   1.303     NaN

# %%
data1.merge(data2, how='outer', on='x1')
# Out:
#   x1      x2      x3
# 0  a  11.432  20.784
# 1  b   1.303     NaN
# 2  c  99.906     NaN
# 3  d     NaN  20.784

# %%
data1.merge(data2, how='left', left_on='x1', right_on='x1')
# Out:
#   x1      x2      x3
# 0  a  11.432  20.784
# 1  b   1.303     NaN
# 2  c  99.906     NaN

# %%
pd.concat([data1, data2], axis=0)
# Out:
#   x1      x2      x3
# 0  a  11.432     NaN
# 1  b   1.303     NaN
# 2  c  99.906     NaN
# 0  a     NaN  20.784
# 1  b     NaN     NaN
# 2  d     NaN  20.784

# %%
pd.concat([data1, data2], axis=0, ignore_index=True)
# Out:
#   x1      x2      x3
# 0  a  11.432     NaN
# 1  b   1.303     NaN
# 2  c  99.906     NaN
# 3  a     NaN  20.784
# 4  b     NaN     NaN
# 5  d     NaN  20.784

# %%
pd.concat([data1, data2], axis=1)
# Out:
#   x1      x2 x1      x3
# 0  a  11.432  a  20.784
# 1  b   1.303  b     NaN
# 2  c  99.906  d  20.784

# %% [markdown]
# ## Correlation

# %%
iris = pd.read_csv('Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
corr = iris.corr()

# %%
corr
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
plt.figure(figsize=(10,8)) 
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
           annot=True)
plt.show()
